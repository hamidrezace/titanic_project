# %% [markdown]
# **Importing the libaries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# **Reading the data:**

# %%
def read_data():
    train_data = pd.read_csv('C:/Users/HamidReza/Desktop/train.csv')
    print("Train data imported successfully")
    
    print(" ")
    
    test_data = pd.read_csv('C:/Users/HamidReza/Desktop/test.csv')
    print("Test data imported successfully")
    return train_data , test_data

train_data , test_data = read_data()
combine = [train_data , test_data]
# Out:
# Train data imported successfully
#
# Test data imported successfully

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# **Discovering the features:**

# %%
print("Train data features are:\n")
print(train_data.columns.values)
print('\n')
print("Test data features are:\n")
print(train_data.columns.values)
# Out:
# Train data features are:
#
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']
#
#
# Test data features are:
#
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %% [markdown]
# **Discovering the features types:**

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# **Discovering the missed values:**

# %%
print(train_data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(test_data.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **Discovering the features correlation with Survived:**

# %%
#Use the function to display multiple graphs

def survived_bar_plot(feature):
    plt.figure(figsize = (6,4))
    sbn.barplot(data = train_data , x = feature , y = "Survived").set_title(f"{feature} Vs Survived")
    plt.show()

# %%
survived_bar_plot('Sex')

# %%
survived_bar_plot("Pclass")

# %%
survived_bar_plot("Parch")

# %%
survived_bar_plot("SibSp")

# %% [markdown]
# **Drop unuseful features:**

# %%
train_data.drop(columns = ["PassengerId"] , inplace=True )

for dataset in combine:
 dataset.drop(columns = ["Ticket" , "Cabin"] , inplace= True)

train_data.drop(['Name'], axis=1 , inplace = True)
test_data.drop(['Name'], axis=1 , inplace = True)

# %%
train_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# **Converting Categorical Features to Numerical and Filling Missed Values:**

# %%
#Embarked

train_data.Embarked.fillna(train_data.Embarked.dropna().max(), inplace= True)

for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].dropna().map({'S':0,'C':1,'Q':2}).astype(int)

# %%
#Sex

train_data.Sex.fillna(train_data.Sex.dropna().max(), inplace= True)

for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# %%
#Age

train_data.Age.fillna(train_data.Age.dropna().median(), inplace= True)
test_data.Age.fillna(train_data.Age.dropna().median(), inplace= True)

# %%
#Fare

test_data.Fare.fillna(test_data.Fare.dropna().median() , inplace= True)

# %%
train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         0
# 1           1       1    1  38.0      1      0  71.2833         1
# 2           1       3    1  26.0      0      0   7.9250         0
# 3           1       1    1  35.0      1      0  53.1000         0
# 4           0       3    0  35.0      0      0   8.0500         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000         0
# 887         1       1    1  19.0      0      0  30.0000         0
# 888         0       3    1  28.0      1      2  23.4500         0
# 889         1       1    0  26.0      0      0  30.0000         1
# 890         0       3    0  32.0      0      0   7.7500         2
#
# [891 rows x 8 columns]

# %%
#Recheck missing values:

print(train_data.isnull().sum())
print('-'*20)
print(test_data.isnull().sum())
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
# --------------------
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# **Creating Bands:**

# %%
#AgeBand

train_data['AgeBand'] = pd.cut(train_data['Age'], 5)
train_data[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#             AgeBand  Survived
# 0    (0.34, 16.336]  0.550000
# 1  (16.336, 32.252]  0.344168
# 2  (32.252, 48.168]  0.404255
# 3  (48.168, 64.084]  0.434783
# 4    (64.084, 80.0]  0.090909

# %%
for dataset in combine:    
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

# %%
#FareBand

train_data['FareBand'] = pd.cut(train_data['Fare'], 4)
train_data[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=False)
# Out:
#              FareBand  Survived
# 3  (384.247, 512.329]  1.000000
# 2  (256.165, 384.247]  0.666667
# 1  (128.082, 256.165]  0.724138
# 0   (-0.512, 128.082]  0.368113

# %%
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

# %%
#remove bands

train_data.drop(['AgeBand'], axis=1 , inplace = True)
train_data.drop(['FareBand'], axis=1 , inplace = True)

# %%
train_data
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0           0       3    0  1.0      1      0     0         0
# 1           1       1    1  2.0      1      0     3         1
# 2           1       3    1  1.0      0      0     1         0
# 3           1       1    1  2.0      1      0     3         0
# 4           0       3    0  2.0      0      0     1         0
# ..        ...     ...  ...  ...    ...    ...   ...       ...
# 886         0       2    0  1.0      0      0     1         0
# 887         1       1    1  1.0      0      0     2         0
# 888         0       3    1  1.0      1      2     2         0
# 889         1       1    0  1.0      0      0     2         1
# 890         0       3    0  1.0      0      0     0         2
#
# [891 rows x 8 columns]

# %% [markdown]
# **Data Engineering:**

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

train_data.drop(['Parch', 'SibSp'], axis=1 , inplace = True)
test_data.drop(['Parch', 'SibSp'], axis=1 , inplace = True)    

train_data[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived' , ascending= False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
# Create new feature of family size

for dataset in combine:
    dataset['Single'] = dataset['FamilySize'].map(lambda s: 1 if s == 1 else 0)
    dataset['SmallF'] = dataset['FamilySize'].map(lambda s: 1 if  s == 2  else 0)
    dataset['MediumF'] = dataset['FamilySize'].map(lambda s: 1 if 3 <= s <= 4 else 0)
    dataset['LargeF'] = dataset['FamilySize'].map(lambda s: 1 if s >= 5 else 0)

    
train_data.drop(columns = ["FamilySize"] , inplace = True)
test_data.drop(columns = ["FamilySize"] , inplace = True)

# %%
train_data
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Single  SmallF  MediumF  \
# 0           0       3    0  1.0     0         0       0       1        0
# 1           1       1    1  2.0     3         1       0       1        0
# 2           1       3    1  1.0     1         0       1       0        0
# 3           1       1    1  2.0     3         0       0       1        0
# 4           0       3    0  2.0     1         0       1       0        0
# ..        ...     ...  ...  ...   ...       ...     ...     ...      ...
# 886         0       2    0  1.0     1         0       1       0        0
# 887         1       1    1  1.0     2         0       1       0        0
# 888         0       3    1  1.0     2         0       0       0        1
# 889         1       1    0  1.0     2         1       1       0        0
# 890         0       3    0  1.0     0         2       1       0        0
#
#      LargeF
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 886       0
# 887       0
# 888       0
# 889       0
# 890       0
#
# [891 rows x 10 columns]

# %% [markdown]
# **Modeling:**

# %%
#Importing the libaries:

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier , VotingClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve

# %%
#Preparing Data For Training:

Y_train = train_data["Survived"]
X_train = train_data.drop(["Survived"],axis = 1)
Test = test_data.drop(["PassengerId"],axis = 1)

# %%
# Cross validate model with Kfold stratified cross val
kfold = StratifiedKFold(n_splits=10)

# SVC classifier
SVMC = SVC(probability=True)
svc_param_grid = {'kernel': ['rbf'], 
                  'gamma': [ 0.001,0.01,0.1 ,1],
                  'C': [1,10, 50, 100,200,300, 1000]}

gsSVMC = GridSearchCV(SVMC,param_grid = svc_param_grid, cv=kfold, scoring="accuracy", n_jobs= 4, verbose = 2)

gsSVMC.fit(X_train,Y_train)

SVMC_best = gsSVMC.best_estimator_

# Best score
gsSVMC.best_score_
# Out:
# Fitting 10 folds for each of 28 candidates, totalling 280 fits
# 0.8238451935081148

# %%
#RFC Parameters tunning 

RFC = RandomForestClassifier()

# Search grid for optimal parameters
rf_param_grid = {"max_depth": [None],
              "max_features": [1, 3 ,10],
              "min_samples_split": [2, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [False],
              "n_estimators" :[100,800],
              "criterion": ["gini"]}


gsRFC = GridSearchCV(RFC,param_grid = rf_param_grid, scoring="accuracy", n_jobs= 4, verbose = 1)

gsRFC.fit(X_train,Y_train)

RFC_best = gsRFC.best_estimator_

# Best score
gsRFC.best_score_
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 90 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py", line 187, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py", line 308, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\HamidReza\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.802492   0.802492   0.80585651 0.80361559 0.81260436 0.81260436
#  0.81822861 0.81710502 0.82159312 0.81822861 0.81262319 0.81261063
#  0.80026991 0.80473919 0.8081037  0.80361559 0.81035717 0.80586278
#  0.80136212 0.8013684  0.80361559 0.80361559 0.80923985 0.80699893
#  0.81708618 0.81373423 0.81373423 0.81373423 0.81373423 0.80924612
#  0.80474546 0.80361559 0.80586278 0.80586906 0.80474546 0.80586906
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# 0.8215931203314293

# %%
#Generate a simple plot of the test and training learning curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

g = plot_learning_curve(gsSVMC.best_estimator_,"SVC learning curves",X_train,Y_train,cv=kfold)
g = plot_learning_curve(gsRFC.best_estimator_,"RF mearning curves",X_train,Y_train,cv=kfold)

# %%
votingC = VotingClassifier(estimators=[('rfc', RFC_best),
('svc', SVMC_best)], voting='soft', n_jobs=4)

votingC = votingC.fit(X_train, Y_train)

# %%
test_Survived = pd.Series(votingC.predict(Test), name="Survived")

results = pd.concat([test_data.PassengerId,test_Survived],axis=1)

results.to_csv("ensemble_python_voting.csv",index=False)

# %%
results
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
